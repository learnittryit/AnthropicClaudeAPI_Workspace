# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 7.333333333333333

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Parse S3 Bucket Name from URI\n\nHere's a solution to extract the bucket name from an S3 URI:\n\n```python\ndef extract_s3_bucket(s3_uri: str) -> str:\n    \"\"\"\n    Extract the bucket name from an S3 URI.\n    \n    Args:\n        s3_uri: S3 URI in the format 's3://bucket-name/path/to/file'\n    \n    Returns:\n        The bucket name\n    \n    Raises:\n        ValueError: If the URI format is invalid\n    \"\"\"\n    if not s3_uri.startswith('s3://'):\n        raise ValueError(f\"Invalid S3 URI format: {s3_uri}\")\n    \n    # Remove 's3://' prefix\n    uri_without_prefix = s3_uri[5:]\n    \n    # Split by '/' and take the first part (bucket name)\n    bucket_name = uri_without_prefix.split('/')[0]\n    \n    if not bucket_name:\n        raise ValueError(\"Bucket name cannot be empty\")\n    \n    return bucket_name\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        \"s3://my-bucket/path/to/file.txt\",\n        \"s3://my-bucket/file.txt\",\n        \"s3://my-bucket/\",\n        \"s3://my-bucket\",\n        \"s3://another-bucket-123/deep/nested/path/file.txt\",\n    ]\n    \n    for uri in test_cases:\n        bucket = extract_s3_bucket(uri)\n        print(f\"URI: {uri}\")\n        print(f\"Bucket: {bucket}\\n\")\n```\n\n**Output:**\n```\nURI: s3://my-bucket/path/to/file.txt\nBucket: my-bucket\n\nURI: s3://my-bucket/file.txt\nBucket: my-bucket\n\nURI: s3://my-bucket/\nBucket: my-bucket\n\nURI: s3://my-bucket\nBucket: my-bucket\n\nURI: s3://another-bucket-123/deep/nested/path/file.txt\nBucket: another-bucket-123\n```\n\n## Alternative Solutions\n\n### Using Regular Expressions\n```python\nimport re\n\ndef extract_s3_bucket_regex(s3_uri: str) -> str:\n    \"\"\"Extract bucket name using regex.\"\"\"\n    match = re.match(r's3://([^/]+)', s3_uri)\n    if not match:\n        raise ValueError(f\"Invalid S3 URI format: {s3_uri}\")\n    return match.group(1)\n```\n\n### Using urllib\n```python\nfrom urllib.parse import urlparse\n\ndef extract_s3_bucket_urllib(s3_uri: str) -> str:\n    \"\"\"Extract bucket name using urllib.\"\"\"\n    parsed = urlparse(s3_uri)\n    if parsed.scheme != 's3':\n        raise ValueError(f\"Invalid S3 URI format: {s3_uri}\")\n    return parsed.netloc\n```\n\nAll three approaches work correctly and handle various S3 URI formats!",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI (e.g., 's3://my-bucket/path/to/file.txt') and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 7,
#     "reasoning": "The solution effectively solves the core task with a straightforward, working implementation. The primary function is well-documented and includes appropriate error handling. However, the alternative urllib solution contains a bug that undermines confidence in the alternatives. Additionally, the lack of bucket name validation against AWS naming conventions and missing support for S3 URI variants limits real-world applicability. The solution would benefit from AWS naming rule validation and a corrected urllib example."
#   },
#   {
#     "output": "# AWS Lambda Function JSON Configuration\n\n```json\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Role\": \"arn:aws:iam::123456789012:role/lambda-execution-role\",\n  \"Handler\": \"index.handler\",\n  \"Timeout\": 30,\n  \"MemorySize\": 256,\n  \"Description\": \"AWS Lambda function configuration\",\n  \"Environment\": {\n    \"Variables\": {}\n  },\n  \"Tags\": {\n    \"Environment\": \"development\",\n    \"Application\": \"my-app\"\n  }\n}\n```\n\n## Configuration Details\n\n| Parameter | Value | Description |\n|-----------|-------|-------------|\n| **FunctionName** | `my-lambda-function` | Unique name for the Lambda function |\n| **Runtime** | `python3.11` | Python 3.11 runtime environment |\n| **Timeout** | `30` | Maximum execution time in seconds |\n| **MemorySize** | `256` | Memory allocation in MB |\n| **Role** | ARN string | IAM execution role (required) |\n| **Handler** | `index.handler` | Entry point for the function |\n\n## Minimal Configuration\n\n```json\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Timeout\": 30,\n  \"MemorySize\": 256\n}\n```\n\n## AWS CLI Deployment Example\n\n```bash\naws lambda create-function \\\n  --function-name my-lambda-function \\\n  --runtime python3.11 \\\n  --timeout 30 \\\n  --memory-size 256 \\\n  --role arn:aws:iam::123456789012:role/lambda-execution-role \\\n  --handler index.handler \\\n  --zip-file fileb://function.zip\n```",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that includes function name, runtime (Python 3.11), timeout (30 seconds), and memory size (256 MB)",
#       "format": "json"
#     },
#     "score": 8,
#     "reasoning": "The solution correctly fulfills the core task requirements with accurate JSON syntax and proper parameter values. The documentation is thorough and helpful, including practical CLI examples. However, the solution could be clearer about distinguishing required from optional fields, and placeholder values should have more explicit replacement instructions. The Role ARN is technically required for actual deployment but wasn't explicitly mentioned in the original task."
#   },
#   {
#     "output": "# AWS IAM Role ARN Validator\n\nHere's a comprehensive solution to validate AWS IAM role ARN format:\n\n```python\nimport re\nfrom typing import Tuple\n\ndef is_valid_iam_role_arn(arn: str) -> bool:\n    \"\"\"\n    Validates if a given string is a valid AWS IAM role ARN format.\n    \n    AWS IAM Role ARN Format:\n    arn:aws:iam::account-id:role/role-name\n    \n    Args:\n        arn (str): The ARN string to validate\n        \n    Returns:\n        bool: True if valid IAM role ARN, False otherwise\n    \"\"\"\n    if not arn or not isinstance(arn, str):\n        return False\n    \n    # AWS IAM Role ARN regex pattern\n    # Format: arn:aws:iam::account-id:role/role-name\n    pattern = r'^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9+=,.@\\-_/]{1,64}$'\n    \n    return bool(re.match(pattern, arn))\n\n\ndef validate_iam_role_arn_detailed(arn: str) -> Tuple[bool, str]:\n    \"\"\"\n    Validates AWS IAM role ARN with detailed error messages.\n    \n    Args:\n        arn (str): The ARN string to validate\n        \n    Returns:\n        Tuple[bool, str]: (is_valid, error_message)\n    \"\"\"\n    # Check if input is a string\n    if not isinstance(arn, str):\n        return False, \"Input must be a string\"\n    \n    if not arn:\n        return False, \"ARN cannot be empty\"\n    \n    # Split by colons\n    parts = arn.split(':')\n    \n    if len(parts) != 6:\n        return False, f\"ARN must have 6 parts separated by colons, got {len(parts)}\"\n    \n    partition, service, resource_type, account_id, resource = parts[0], parts[1], parts[2], parts[3], parts[4:]\n    resource = ':'.join(resource)\n    \n    # Validate partition\n    if partition != 'arn':\n        return False, f\"Invalid partition '{partition}', expected 'arn'\"\n    \n    # Validate service\n    if service != 'aws':\n        return False, f\"Invalid service '{service}', expected 'aws'\"\n    \n    # Validate resource type\n    if resource_type != 'iam':\n        return False, f\"Invalid resource type '{resource_type}', expected 'iam'\"\n    \n    # Validate account ID (must be empty for IAM role ARN)\n    if account_id != '':\n        return False, f\"Account ID must be empty, got '{account_id}'\"\n    \n    # Validate resource format (role/role-name)\n    if not resource.startswith('role/'):\n        return False, f\"Resource must start with 'role/', got '{resource}'\"\n    \n    role_name = resource[5:]  # Remove 'role/' prefix\n    \n    if not role_name:\n        return False, \"Role name cannot be empty\"\n    \n    # Validate role name (1-64 characters, alphanumeric and allowed special chars)\n    if len(role_name) > 64:\n        return False, f\"Role name cannot exceed 64 characters, got {len(role_name)}\"\n    \n    if not re.match(r'^[a-zA-Z0-9+=,.@\\-_/]+$', role_name):\n        return False, f\"Role name contains invalid characters: '{role_name}'\"\n    \n    return True, \"Valid IAM role ARN\"\n\n\n# Test cases\nif __name__ == \"__main__\":\n    test_cases = [\n        # Valid ARNs\n        (\"arn:aws:iam::123456789012:role/my-role\", True),\n        (\"arn:aws:iam::123456789012:role/service-role\", True),\n        (\"arn:aws:iam::999999999999:role",
#     "test_case": {
#       "task": "Write a Python function that validates if a given string is a valid AWS IAM role ARN format",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution demonstrates solid understanding of AWS IAM ARN structure and provides dual validation methods with good error handling. The regex pattern is accurate and the logic is sound. However, the incomplete test cases section is a significant issue that prevents full verification of correctness. The missing support for alternative AWS partitions and the minor bug in string parsing are secondary concerns but worth noting for production use. Overall, this is a competent solution with good structure but incomplete presentation."
#   }
# ]
