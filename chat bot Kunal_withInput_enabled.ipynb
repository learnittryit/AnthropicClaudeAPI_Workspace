# %% [markdown]
# ## Make a sample chat bot
#
# steps
# 1. load api key to hit API <br>
# 2. make 3 essential functions <br>
#     func1 - user message <br>
#     func2 - assistant message <br>
#     func3 - chat and call model <br>

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic
clientfunc = Anthropic()
model ="claude-sonnet-4-0"

# %%
## user func
def add_user_messages(messages,text):
    user_message = {"role":"user","content":text}
    messages.append(user_message)

## assistant func
def add_assistant_messages(messages,text):
    assistant_message = {"role":"assistant","content":text}
    messages.append(assistant_message)

## chat func
def chat(combinesMessages):
    message = clientfunc.messages.create(
        model=model,
        max_tokens=1000,
        messages=combinesMessages)
    return message.content[0].text

# %%
## Making inital list of messages
messages = []

## Loop 5 times to limit model hit
while True:
    ## Get user input and the ## user followup question and
    user_input = input("Enter your question: ")
    print(user_input)
    
    ## Add to usrer messages list and print
    add_user_messages(messages, user_input)
    print(messages)

    ## call chat function and print response
    response = chat(messages)
    print(response)

    ## generate context by appending assistent message to messages list
    add_assistant_messages(messages,response)
    print(messages)
    print("-----",response,"\n-----\n")


    #finalresponse = chat(messages)
# Out:
# what is 3*3
# [{'role': 'user', 'content': 'what is 3*3'}]
# /var/folders/hl/xvs6dldn7nl02zjtlhj9vgbr0000gn/T/ipykernel_45511/3765284208.py:13: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = clientfunc.messages.create(
# 3 × 3 = 9
# [{'role': 'user', 'content': 'what is 3*3'}, {'role': 'assistant', 'content': '3 × 3 = 9'}]
# ----- 3 × 3 = 9
# -----
#
# and times 3
# [{'role': 'user', 'content': 'what is 3*3'}, {'role': 'assistant', 'content': '3 × 3 = 9'}, {'role': 'user', 'content': 'and times 3'}]
# 9 × 3 = 27
# [{'role': 'user', 'content': 'what is 3*3'}, {'role': 'assistant', 'content': '3 × 3 = 9'}, {'role': 'user', 'content': 'and times 3'}, {'role': 'assistant', 'content': '9 × 3 = 27'}]
# ----- 9 × 3 = 27
# -----
#
# and times 30
# ...
