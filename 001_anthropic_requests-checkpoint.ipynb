# %% [markdown]
# ##### 1. Insatall dependencies
# ##### 2. Load env vars
# ##### 3. Create API client
# ##### 4. Make a Request

# %%
## Install dependencies

# %%
## Load env variables

# %%
## Create API client

# %%
## Make A Request
