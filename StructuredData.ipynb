# %% [markdown]
# #### Structured Data - JSON data between ''' '''.json <br>
# step 1 - assistance message prefelling is removed <br>
# step 2 - stop_sequences['''] = param to stop once this sequence is char is arrived

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic
clientfunc = Anthropic()
model ="claude-sonnet-4-0"

# %%
## user func
def add_user_messages(messages,text):
    user_message = {"role":"user","content":text}
    messages.append(user_message)

## assistant func
def add_assistant_messages(messages,text):
    assistant_message = {"role":"assistant","content":text}
    messages.append(assistant_message)

## chat func
def chat(messages,stop_sequences):
    message = clientfunc.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
        stop_sequences=stop_sequences)
    return message.content[0].text

# %%
messages = []
add_user_messages(messages,"count from 1 to 10")

clientfunc.messages.create(
    model=model,
    max_tokens=1000,
    messages=messages,
    stop_sequences=["5","3"]).content[0].text
# Out:
# /var/folders/hl/xvs6dldn7nl02zjtlhj9vgbr0000gn/T/ipykernel_3597/3329761558.py:4: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   clientfunc.messages.create(
# '1, 2, '

# %%
messages = []
add_user_messages(messages,"Generate a list of top 5 countries and its populatioon as a json")

chat(messages)
# Out:
# /var/folders/hl/xvs6dldn7nl02zjtlhj9vgbr0000gn/T/ipykernel_3597/3765284208.py:13: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = clientfunc.messages.create(
# ...

# %%
messages = []
add_user_messages(messages,"Generate a list of top 5 countries and its populatioon as a json")
add_assistant_messages(messages,"```json")
text=chat(messages,stop_sequences=["```"])
text
# Out:
# /var/folders/hl/xvs6dldn7nl02zjtlhj9vgbr0000gn/T/ipykernel_3597/346361413.py:13: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = clientfunc.messages.create(
# ...

# %%
import json
json.loads(text.strip())
# Out:
# {'top_5_countries_by_population': [{'rank': 1,
#    'country': 'China',
#    'population': 1412000000,
#    'population_formatted': '1.41 billion'},
#   {'rank': 2,
#    'country': 'India',
#    'population': 1380000000,
#    'population_formatted': '1.38 billion'},
#   {'rank': 3,
#    'country': 'United States',
#    'population': 331000000,
#    'population_formatted': '331 million'},
#   {'rank': 4,
#    'country': 'Indonesia',
#    'population': 273500000,
#    'population_formatted': '273.5 million'},
#   {'rank': 5,
#    'country': 'Pakistan',
#    'population': 225200000,
#    'population_formatted': '225.2 million'}],
#  'note': 'Population figures are approximate and based on 2023 estimates',
#  'last_updated': '2023'}
