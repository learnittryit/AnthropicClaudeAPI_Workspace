# %% [markdown]
# ##### How we can customise tone and style of respons, which claude generates
# System Prompt - It guide claude how to responde, it controles <font color="red"><b>style and tone of response<b></font>
# ##### Response should
# - eg: do this
# ##### Response Should not
# - eg: dont do this

# %% [markdown]
# ## Math Tutor

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic
clientfunc = Anthropic()
model ="claude-sonnet-4-0"

# %%
## user func
def add_user_messages(messages,text):
    user_message = {"role":"user","content":text}
    messages.append(user_message)

## assistant func
def add_assistant_messages(messages,text):
    assistant_message = {"role":"assistant","content":text}
    messages.append(assistant_message)

## chat func
def chat(messages,system=None):

    params = {
        "model":model,
        "max_tokens":1000,
        "messages":messages
    }

    if system:
        params["system"] = system

    message = clientfunc.messages.create(**params)
    return message.content[0].text

# %%
## Putting all together and call API
messages = []

system_prompt = """
write a very consise python program which prints string of duplicate characters in the given string
"""

add_user_messages(messages,"write a python program which prints string of duplicate characters in the given string")
print(messages)

response = chat(messages)
print(response)
# Out:
# [{'role': 'user', 'content': 'write a python program which prints string of duplicate characters in the given string'}]
# /var/folders/hl/xvs6dldn7nl02zjtlhj9vgbr0000gn/T/ipykernel_60294/2289506807.py:23: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = clientfunc.messages.create(**params)
# Here are several Python programs to find and print duplicate characters in a string:
#
# ## Method 1: Using Dictionary (Most Common Approach)
#
# ```python
# def find_duplicates_dict(string):
#     """Find duplicate characters using dictionary"""
#     char_count = {}
#     duplicates = []
#
#     # Count frequency of each character
#     for char in string:
#         if char != ' ':  # Ignore spaces (optional)
#             char_count[char] = char_count.get(char, 0) + 1
#
#     # Find characters with count > 1
#     for char, count in char_count.items():
#         if count > 1:
#             duplicates.append(char)
#
#     return duplicates
#
# # Test the function
# test_string = "programming"
# duplicates = find_duplicates_dict(test_string)
# print(f"String: {test_string}")
# print(f"Duplicate characters: {duplicates}")
# print(f"Duplicate characters as string: {''.join(duplicates)}")
# ```
#
# ## Method 2: Using Collections Counter
#
# ```python
# from collections import Counter
#
# def find_duplicates_counter(string):
#     """Find duplicate characters using Counter"""
#     # Count characters (excluding spaces)
#     char_count = Counter(char for char in string if char != ' ')
#
#     # Get characters with count > 1
#     duplicates = [char for char, count in char_count.items() if count > 1]
#
#     return duplicates
#
# # Test the function
# test_string = "hello world"
# duplicates = find_duplicates_counter(test_string)
# print(f"String: {test_string}")
# print(f"Duplicate characters: {duplicates}")
# ```
#
# ## Method 3: Using Set (Track Seen Characters)
#
# ```python
# def find_duplicates_set(string):
#     """Find duplicate characters using sets"""
#     seen = set()
#     duplicates = set()
#
#     for char in string:
#         if char != ' ':  # Ignore spaces
#             if char in seen:
#                 duplicates.add(char)
#             else:
#                 seen.add(char)
#
#     return list(duplicates)
#
# # Test the function
# test_string = "abcdefghijklmnopqrstuvwxyzabc"
# duplicates = find_duplicates_set(test_string)
# print(f"String: {test_string}")
# print(f"Duplicate characters: {duplicates}")
# ```
#
# ## Method 4: Complete Program with Multiple Options
#
# ```python
# from collections import Counter
#
# def find_duplicates_comprehensive(string, include_spaces=False, case_sensitive=True):
#     """
#     Comprehensive function to find duplicate characters
#
#     Args:
#         string: Input string
#         include_spaces: Whether to include spaces in analysis
#         case_sensitive: Whether to consider case when finding duplicates
#     """
#     # Process string based on parameters
#     processed_string = string
#     if not case_sensitive:
#         processed_string = string.lower()
#
#     # Count characters
#     char_count = {}
#     for char in processed_string:
#         if include_spaces or char != ' ':
#             char_count[char] = char_count.get(char, 0) + 1
#
#     # Find duplicates
#     duplicates = [char for char, count in char_count.items() if count > 1]
#
#     return duplicates, char_count
#
# def main():
#     """Main function to demonstrate different scenarios"""
#
#     test_strings = [
#         "programming",
#         "hello world",
#         "Python Programming",
#         "aabbccdef",
#         "abcdefghijk"
#     ]
#
#     print("=" * 50)
#     print("DUPLICATE CHARACTER FINDER")
#     print("=" * 50)
#
#     for test_string in test_strings:
#         print(f"\nAnalyzing: '{test_string}'")
#         print("-" * 40)
#
#         # Case sensitive, no spaces
#         duplicates, char_count = find_duplicates_comprehensive(test_string, include_spaces=False, case_sensitive=True)
#         print(f"Case sensitive (no spaces): {duplicates}")

# %%
print("\n-------------------------------------------\n")
response_with_system_prompt = chat(messages,system_prompt)
print(response_with_system_prompt)
# Out:
# -------------------------------------------
# /var/folders/hl/xvs6dldn7nl02zjtlhj9vgbr0000gn/T/ipykernel_60294/2289506807.py:23: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = clientfunc.messages.create(**params)
# Here's a concise Python program that prints duplicate characters in a given string:
#
# ```python
# def find_duplicates(s):
#     seen = set()
#     duplicates = set()
#
#     for char in s:
#         if char in seen:
#             duplicates.add(char)
#         else:
#             seen.add(char)
#
#     return ''.join(duplicates)
#
# # Example usage
# string = input("Enter a string: ")
# result = find_duplicates(string)
#
# if result:
#     print(f"Duplicate characters: {result}")
# else:
#     print("No duplicate characters found")
# ```
#
# **Alternative one-liner approach:**
#
# ```python
# s = input("Enter a string: ")
# duplicates = ''.join(set([char for char in s if s.count(char) > 1]))
# print(f"Duplicate characters: {duplicates}" if duplicates else "No duplicates")
# ```
#
# **Example output:**
# ```
# Enter a string: hello world
# Duplicate characters: ol
# ```
#
# The program works by:
# 1. Using two sets: one to track seen characters and another for duplicates
# 2. Iterating through each character in the string
# 3. If a character is already seen, it's added to duplicates
# 4. Finally, joining all duplicate characters into a string
