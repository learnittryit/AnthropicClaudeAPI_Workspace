# %% [markdown]
# ## Make a sample chat bot
#
# steps
# 1. load api key to hit API <br>
# 2. make 3 essential functions <br>
#     func1 - user message <br>
#     func2 - assistant message <br>
#     func3 - chat and call model <br>

# %%
from dotenv import load_dotenv
load_dotenv()

from anthropic import Anthropic
clientfunc = Anthropic()
model ="claude-sonnet-4-0"

# %%
## user func
def add_user_messages(messages,text):
    user_message = {"role":"user","content":text}
    messages.append(user_message)

## assistant func
def add_assistant_messages(messages,text):
    assistant_message = {"role":"assistant","content":text}
    messages.append(assistant_message)

## chat func
def chat(combinesMessages,temp=0.0):
    print("temperature is ",temp)
    message = clientfunc.messages.create(
        model=model,
        max_tokens=1000,
        messages=combinesMessages,
        temperature=temp)
    return message.content[0].text

# %%
## Putting all together and call API
messages = []

add_user_messages(messages,"Generate one sentence movie idea")
print(messages)

response = chat(messages,temp=1.0)
print(response)
# Out:
# [{'role': 'user', 'content': 'Generate one sentence movie idea'}]
# temperature is  1.0
# /var/folders/hl/xvs6dldn7nl02zjtlhj9vgbr0000gn/T/ipykernel_4110/22650494.py:14: DeprecationWarning: The model 'claude-sonnet-4-0' is deprecated and will reach end-of-life on June 15th, 2026.
# Please migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.
#   message = clientfunc.messages.create(
# A time-traveling librarian discovers that someone is systematically erasing pivotal moments from history by stealing the original books that inspired them.
